# %%
# !conda create -n TFM python=3.9
# !conda activate TFM
# !pip install -U openai-whisper
# !pip install pyannote.audio
# !pip install setuptools
# =59.5.0
#!pip install speechbrain 
# = 0.5.16
# !pip install pip install ffmpeg
# !pip install huggingsound
# Out:
# ^C
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Obtaining dependency information for huggingsound from https://files.pythonhosted.org/packages/97/b4/0e6ba4ca54ee25577b66a382c1e151fcdd23d9a5efc44e30949de42af355/huggingsound-0.1.6-py3-none-any.whl.metadata
#   Using cached huggingsound-0.1.6-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Obtaining dependency information for datasets<3.0.0,>=2.6.1 from https://files.pythonhosted.org/packages/9f/8a/3922b6d4a8fb40db454abd5d66b28215b047563564f044de693643d5d07f/datasets-2.19.1-py3-none-any.whl.metadata
#   Using cached datasets-2.19.1-py3-none-any.whl.metadata (19 kB)
# ...

# %%
##extract_audio_from_video(video_path, audio_path)
from moviepy.audio.io.AudioFileClip import AudioFileClip


def extract_audio_from_video(video_path, audio_path):# -> Any:
    from moviepy.editor import VideoFileClip
    # Load the video clip
    clip = VideoFileClip(video_path)
    # Extract the audio from the video clip
    # clip.audio
    audio_clip: AudioFileClip | None = clip.audio
    # # Save the audio clip as WAV file
    audio_clip.write_audiofile(audio_path)
    
    return audio_path

extract_audio_from_video("data/refinamiento_AQ.mp4", "data/refinamiento_AQ_audio.mp3")
# Out:
#
#
# chunk:   0%|          | 25/53236 [00:12<7:18:29,  2.02it/s, now=None]
# MoviePy - Writing audio in data/refinamiento_AQ_audio.mp3
#
#
# chunk:   0%|          | 25/53236 [00:42<25:20:50,  1.71s/it, now=None]
# MoviePy - Done.
# 'data/refinamiento_AQ_audio.mp3'

# %%
import whisper
from pyannote.audio import Pipeline
from pyannote_whisper import utils

pipeline = Pipeline.from_pretrained('pyannote/speaker-diarization-3.0', use_auth_token="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")
model_whisper = whisper.load_model("medium")

# %%
def transcript_whisper(audio_path):
    transcript = model_whisper.transcribe(audio_path)
    return transcript

# %%
# transcript_whisper = transcript_whisper("data/ENDV_audio.wav")
transcript_whisper = model_whisper.transcribe("data/ENDV_audio.wav")

# %%
transcript_whisper['text']
# Out:
# ' Me llamo Quoth. He robado princesas a reyes agólicos. Incendié la ciudad de Trevón. He pasado la noche con Felurian y he despertado vivo y cuerno. Me expulsaron de la universidad a una edad a la que la mayoría todavía no los dejan entrar. He recorrido de noche caminos de los que otros no se atreven a hablar ni siquiera de día. He hablado con dioses, he llamado a mujeres y he escrito canciones que hacen llorar a los bardos. Quizá hayas oído hablar de mí. Esta es mi auténtica historia. El nombre del viento.'

# %%
# transcript_wav2vec2Spanish(audio_path)
## Python 3.9 conda 
from huggingsound import SpeechRecognitionModel
model_wav2vec = SpeechRecognitionModel("jonatasgrosman/wav2vec2-large-xlsr-53-spanish")

def transcript_wav2vec2Spanish(audio_path):
    audio_paths = [audio_path]

    transcriptions = model.transcribe(audio_paths)
    return transcriptions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 ## transcript_wav2vec2Spanish(audio_path)
# ----> 2 from huggingsound import SpeechRecognitionModel
#       3 model_wav2vec = SpeechRecognitionModel("jonatasgrosman/wav2vec2-large-xlsr-53-spanish")
#       5 def transcript_wav2vec2Spanish(audio_path):
#
# ModuleNotFoundError: No module named 'huggingsound'

# %%
## Python 3.9 conda 
# transcript_wav2vec2Spanish = transcript_wav2vec2Spanish("data/ENDV_audio.wav")
transcript_wav2vec2Spanish = model_wav2vec.transcribe(["data/ENDV_audio.wav"])
# Out:
# 100%|██████████| 1/1 [01:05<00:00, 65.18s/it]
# [{'transcription': 'me llamo quouth he robado princesas a reyes agólicos incendié la ciudad de fremon he pasado la noche con felurian y he despertado vivo y cuerno me expulsaron de la universidad a una ida a la que la mayoría todavía no los dejan entrar he recorrido de noche caminos de los que otros no se atreven a hablar ni siquiera de día he hablado con dioses he hamado a mujeres y he escrito canciones que hacen llorar a los bardos quizá hayas oído al artere esta es mi auténtica historiael nombre del viento',
#   'start_timestamps': [4260,
#    4320,
#    4360,
#    4420,
#    4480,
#    4520,
#    4600,
#    4640,
#    4700,
#    4800,
#    4860,
#    4940,
#    5020,
#    5200,
#    5240,
#    5300,
#    6380,
#    6420,
#    6480,
#    6560,
#    6600,
#    6680,
#    6720,
#    6780,
#    6820,
#    6860,
#    6920,
#    6960,
#    7000,
#    7060,
#    7160,
#    7240,
#    7320,
#    7400,
#    7460,
#    7500,
#    7560,
# ...

# %%
# Probar NVIDIA: https://huggingface.co/nvidia/stt_es_conformer_transducer_large
# https://huggingface.co/facebook/wav2vec2-large-es-voxpopuli
# https://huggingface.co/zuazo/whisper-medium-es
speechTranscript = model.transcribe("data/yo.m4a")

# %%
### Cargar audio

# Procesar video -> Audio

# Procesar audio -> Texto
